# %% [markdown]
# ### Informed Learner

# %%
# add parent directory to path
import sys
sys.path.append('..')
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import argparse
from tqdm.notebook import tqdm
from tqdm.auto import tqdm as tqdma
from datasets.create_dataset import create_dataset
from models.create_model import create_model
import numpy as np

import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def sort_data(vec2sort: np.ndarray, *data_: tuple[np.ndarray,...]):
    sort_ids = np.argsort(vec2sort)
    sorted_data_ = [None] * len(data_)
    for i, data in enumerate(data_):
        sorted_data_[i] = np.zeros_like(data)
        if len(data.shape)>1:
            for j in range(data.shape[1]):
                sorted_data_[i][:,j] = data[sort_ids,j]
        else:
            sorted_data_[i] = data[sort_ids]
    if len(data_) > 1:
        return tuple(sorted_data_), sort_ids
    else:
        return sorted_data_[0], sort_ids

# %%
def main(config: argparse.Namespace):
    torch.manual_seed(42)
    device = torch.device('cpu')

    # Create dataset
    phys_config = {
        'n_dof' : config.n_dof,
        'system-type' : config.system_type
    }
    data_parameters = {
        'sequence_length' : config.sequence_length,
        'subsample' : config.subsample,
        'downsample' : config.downsample
    }
    phases = ['train', 'val', 'test']
    full_dataset = create_dataset(phys_config, data_parameters)
    train_size = 1.0
    val_size = 0.0
    test_size = 0.0
    train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, val_size, test_size])
    datasets = {
        'train': train_dataset,
        'val': val_dataset,
        'test': test_dataset
    }
    dataloaders = {
        x: DataLoader(dataset=datasets[x], batch_size=config.batch_size, shuffle=True if x == 'train' else False, num_workers=config.num_workers, pin_memory=True) for x in phases}

    # Create pinn model
    if config.out_channels != 2*config.n_dof:
        raise Exception("Number of network outputs does not match state vector of simulated model")
    pinn_config = {
        'n_dof' : config.n_dof,
        'phys_system_type' : config.phys_system_type,
        'system_discovery' : config.system_discovery,
        'm_' : config.m_,
        'c_' : config.c_,
        'k_' : config.k_,
        'kn_' : config.kn_,
        'alphas' : full_dataset.alphas,
        'param_norms' : {
            'm' : 1.0,
            'c' : 1.0,
            'k' : 10.0,
            'kn' : 10.0
        }
    }
    model = create_model(config.model_type, config.in_channels, config.latent_features, config.out_channels, config.sequence_length, pinn_config)
    criterion = nn.MSELoss(reduction='sum')
    optimizer = optim.Adam(model.parameters(), lr=config.learning_rate, weight_decay=config.weight_decay)
    model.set_switches(config.lambdas)

    # set up plotting and printing
    fig, axs = plt.subplots(3, 1, figsize=(12,12))
    dh = display.display(fig, display_id=True)
    loss_hist = []
    loss_hist_sub = []
    print_step = 1000
    num_obs_samps = len(datasets['train']) * config.sequence_length
    num_col_samps = len(datasets['train']) * config.subsample * config.sequence_length
    t_span_obs = torch.zeros((num_obs_samps)).numpy()  # time vector for observation domain
    obs_state = torch.zeros((num_obs_samps, 2 * config.n_dof))  # all state observations
    t_span_gt = torch.zeros((num_col_samps)).numpy()  # time vector for gt/prediction domain
    ground_truth = torch.zeros((num_col_samps, 3 * config.n_dof + 1)).numpy()  # all data for gound truth (state, time, force)
    predictions = torch.zeros((num_col_samps, 2 * config.n_dof)).numpy()  # all state predictions (same as collocation domain)

    # Training loop
    epoch = 0
    model = model.to(device)
    progress_bar = tqdm(total=config.num_epochs)
    while epoch < config.num_epochs:
        write_string = ''
        write_string += 'Epoch {}\n'.format(epoch)
        for phase in phases:
            phase_loss = 0.
            losses = [0.0] * 4
            write_string += '\tPhase {}\n'.format(phase)
            if phase == 'train':
                model.train()
            else:
                model.eval()
            for i, (sample, coll_data) in enumerate(dataloaders[phase]):
                # parse data sample
                state = sample[..., :2*config.n_dof].to(device).float().requires_grad_()
                t_span = sample[..., 2*config.n_dof].to(device).float().requires_grad_()
                t_coll = coll_data[..., 2*config.n_dof].to(device).float().requires_grad_()
                force = coll_data[..., 2*config.n_dof+1:].to(device).float().requires_grad_()

                inputs = t_span
                targets = state
                t_coll = t_coll.reshape(-1,config.sequence_length)  # unrolls collocation data
                force = force.reshape(-1,config.sequence_length,config.n_dof)

                if phase == 'train':
                    optimizer.zero_grad()
                loss, losses_i, _ = model.loss_func(config.lambdas, inputs, targets, t_coll, force, epoch)
                phase_loss += loss.item()
                losses = [losses[j] + loss_i for j, loss_i in enumerate(losses_i)]
                if phase == 'train':
                    loss.backward()
                    optimizer.step()
                    # model.apply(clipper)
            if phase == 'train':
                loss_hist.append([loss_it.item() for loss_it in losses] + [phase_loss])
            write_string += '\tLoss {}\n'.format(phase_loss)
        if config.system_discovery:
            write_string += '\tSystem Parameters:\tc - {:.4f} [{:.2f}]\tk - {:.4f} [{:.2f}]\tkn - {:.4f} [{:.2f}]\n'.format(
                model.c_[0,0].item()*pinn_config['param_norms']['c'],
                config.c_[0,0].item(),
                model.k_[0,0].item()*pinn_config['param_norms']['k'],
                config.k_[0,0].item(),
                model.kn_[0,0].item()*pinn_config['param_norms']['kn'],
                config.kn_[0,0].item())
        
        if (epoch+1) % print_step == 0:

            for i, (sample, coll_data) in enumerate(dataloaders['train']):
                inpoint_obs = i * config.batch_size * config.sequence_length
                outpoint_obs = (i+1) * config.batch_size * config.sequence_length
                inpoint_col = i * config.batch_size * config.subsample * config.sequence_length
                outpoint_col = (i+1) * config.batch_size * config.subsample * config.sequence_length

                obs_inputs = sample[..., 2 * config.n_dof].to(device).float()
                t_span_obs[inpoint_obs:outpoint_obs] = obs_inputs.numpy().reshape(-1)
                obs_state[inpoint_obs:outpoint_obs,:] = sample[..., :2 * config.n_dof].float().reshape(-1,2*config.n_dof)

                t_coll = coll_data[..., 2 * config.n_dof].to(device).float().requires_grad_()
                pred_inputs = t_coll.reshape(-1, config.sequence_length)

                ground_truth[inpoint_col:outpoint_col,:] = coll_data.reshape(-1, 3 * config.n_dof + 1).cpu().numpy()
                t_span_gt[inpoint_col:outpoint_col] = pred_inputs.reshape(-1).detach().cpu().numpy()
                predictions[inpoint_col:outpoint_col, :] = model(pred_inputs).detach().cpu().reshape(-1, 2 * config.n_dof).numpy()

            (ground_truth, predictions, t_span_gt), _ = sort_data(t_span_gt, ground_truth, predictions, t_span_gt)
            (obs_state, t_span_obs), _ = sort_data(t_span_obs, obs_state, t_span_obs)

            for kinetic in range(2):
                axs[kinetic].cla()
                axs[kinetic].plot(t_span_gt * model.alpha_t.item(),
                                  ground_truth[:, kinetic] * model.alpha_z[kinetic].item(),
                                  label='Exact Solution', color='tab:blue', linewidth=1.0)
                axs[kinetic].plot(t_span_gt * model.alpha_t.item(),
                                  predictions[:, kinetic] * model.alpha_z[kinetic].item(),
                                  label='Prediction', linestyle='--', color='tab:red', linewidth=1.0)
                axs[kinetic].plot(t_span_obs * model.alpha_t.item(),
                                  obs_state[:, kinetic] * model.alpha_z[kinetic].item(),
                                  label='Observation Data', linestyle='None', marker='o',
                                  color='tab:gray', markersize=4)
                axs[kinetic].legend()

            loss_vec = torch.arange(epoch+1)
            loss_step = len(loss_hist) // int(10e3) + 1
            loss_vec = loss_vec[::loss_step]
            loss_hist_sub = loss_hist_sub + loss_hist[::loss_step]
            loss_hist = []

            axs[2].cla()
            linestyles = ['-'] * 4 + ['--']
            colors = ['tab:blue', 'tab:purple', 'tab:red', 'tab:green', 'black']
            labels = ['Observation', 'Continuity', 'Physics', 'IC', 'Total']
            axs[2].set_prop_cycle(linestyle=linestyles, color=colors)
            axs[2].plot(loss_vec,loss_hist_sub)
            axs[2].legend(labels)
            axs[2].set_yscale('log')

            dh.update(fig)
            tqdma.write(write_string)
            
        epoch += 1
        progress_bar.update(1)
    
    progress_bar.close()

    return model

# %%
# parse config
parser = argparse.ArgumentParser(description="Train PINN")

# physical-model arguments
parser.add_argument('--n-dof', type=int, default=1)
parser.add_argument('--system-type', type=str, default='single_dof_duffing')
parser.add_argument('--subsample', type=int, default=16)
parser.add_argument('--downsample', type=int, default=1)

# nn-model arguments
parser.add_argument('--model-type', type=str, default='sdof_pinn')
parser.add_argument('--in-channels', type=int, default=1)
parser.add_argument('--latent-features', type=int, default=32)
parser.add_argument('--out-channels', type=int, default=2)

# pinn arguments
parser.add_argument('--phys-system-type', type=str, default='duffing_sdof')
parser.add_argument('--lambdas', type=dict, default={
    'obs' : 1.0,
    'cc' : 1.0,
    'ode' : 1.0,
    'ic' : 0.0
})
parser.add_argument('--system-discovery', type=bool, default=False)
parser.add_argument('--m-', type=torch.Tensor, default=torch.Tensor([[10.0]]))
parser.add_argument('--c-', type=torch.Tensor, default=torch.Tensor([[1.0]]))
parser.add_argument('--k-', type=torch.Tensor, default=torch.Tensor([[15.0]]))
parser.add_argument('--kn-', type=torch.Tensor, default=torch.Tensor([[100.0]]))

# training arguments
parser.add_argument('--task', type=str, default="instance")
parser.add_argument('--batch-size', type=int, default=4)
parser.add_argument('--num-workers', type=int, default=0)
parser.add_argument('--num-epochs', type=int, default=250000)
parser.add_argument('--sequence-length', type=int, default=1)
parser.add_argument('--learning-rate', type=float, default=5e-4)
parser.add_argument('--weight-decay', type=float, default=0)

args = parser.parse_args(args=[])

model = main(args)
# Out:
# Simulating 1DOF Duffing oscillator...
# Setting\instantiating physical parameters in PINN....
# Setting normalisation constants....
# Setting loss function switches....
#   0%|          | 0/250000 [00:00<?, ?it/s]
# Epoch 999
# 	Phase train
# 	Loss 0.5092983841896057
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 1999
# 	Phase train
# 	Loss 0.5071108564734459
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 2999
# 	Phase train
# 	Loss 0.5086899623274803
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 3999
# 	Phase train
# 	Loss 0.5075685679912567
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 4999
# 	Phase train
# 	Loss 0.5079864412546158
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 5999
# 	Phase train
# 	Loss 0.5066857486963272
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 6999
# 	Phase train
# 	Loss 0.5062528476119041
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 7999
# 	Phase train
# 	Loss 0.5055052936077118
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 8999
# 	Phase train
# 	Loss 0.49912402033805847
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 9999
# 	Phase train
# 	Loss 0.4996234402060509
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 10999
# 	Phase train
# 	Loss 0.4966781884431839
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 11999
# 	Phase train
# 	Loss 0.49443715065717697
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 12999
# 	Phase train
# 	Loss 0.4836503565311432
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 13999
# 	Phase train
# 	Loss 0.46684324741363525
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 14999
# 	Phase train
# 	Loss 0.4194563403725624
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 15999
# 	Phase train
# 	Loss 0.40632786974310875
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 16999
# 	Phase train
# 	Loss 0.4038967117667198
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 17999
# 	Phase train
# 	Loss 0.3758403956890106
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 18999
# 	Phase train
# 	Loss 0.36365196108818054
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 19999
# 	Phase train
# 	Loss 0.35187605768442154
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 20999
# 	Phase train
# 	Loss 0.35450180247426033
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 21999
# 	Phase train
# 	Loss 0.3140966668725014
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 22999
# 	Phase train
# 	Loss 0.276974406093359
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 23999
# 	Phase train
# 	Loss 0.23961386643350124
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 24999
# 	Phase train
# 	Loss 0.19413774460554123
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 25999
# 	Phase train
# 	Loss 0.17022022977471352
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 26999
# 	Phase train
# 	Loss 0.1283841971307993
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 27999
# 	Phase train
# 	Loss 0.09742529410868883
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 28999
# 	Phase train
# 	Loss 0.03491420857608318
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 29999
# 	Phase train
# 	Loss 0.021070705028250813
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 30999
# 	Phase train
# 	Loss 0.016473319265060127
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 31999
# 	Phase train
# 	Loss 0.028589939698576927
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 32999
# 	Phase train
# 	Loss 0.02090022200718522
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 33999
# 	Phase train
# 	Loss 0.005532064678845927
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 34999
# 	Phase train
# 	Loss 0.004569763754261658
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 35999
# 	Phase train
# 	Loss 0.0035773978452198207
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 36999
# 	Phase train
# 	Loss 0.016991007141768932
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 37999
# 	Phase train
# 	Loss 0.006886508548632264
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 38999
# 	Phase train
# 	Loss 0.0014771915739402175
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 39999
# 	Phase train
# 	Loss 0.0012621795176528394
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 40999
# 	Phase train
# 	Loss 0.004647303721867502
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 41999
# 	Phase train
# 	Loss 0.0026704403571784496
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 42999
# 	Phase train
# 	Loss 0.0018261566874571145
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 43999
# 	Phase train
# 	Loss 0.0007999472290975973
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 44999
# 	Phase train
# 	Loss 0.0032402885844931006
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 45999
# 	Phase train
# 	Loss 0.0007329713553190231
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 46999
# 	Phase train
# 	Loss 0.0030591344402637333
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 47999
# 	Phase train
# 	Loss 0.0005838305005454458
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 48999
# 	Phase train
# 	Loss 0.0009099781163968146
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 49999
# 	Phase train
# 	Loss 0.0004564206101349555
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 50999
# 	Phase train
# 	Loss 0.0004858862594119273
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 51999
# 	Phase train
# 	Loss 0.00042040965854539536
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 52999
# 	Phase train
# 	Loss 0.00043756506420322694
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 53999
# 	Phase train
# 	Loss 0.0008323140791617334
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 54999
# 	Phase train
# 	Loss 0.001407337054843083
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 55999
# 	Phase train
# 	Loss 0.00038433167355833575
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 56999
# 	Phase train
# 	Loss 0.00032540357642574236
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 57999
# 	Phase train
# 	Loss 0.001109974182327278
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 58999
# 	Phase train
# 	Loss 0.011507144081406295
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 59999
# 	Phase train
# 	Loss 0.0003153051693516318
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 60999
# 	Phase train
# 	Loss 0.0011074315989390016
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 61999
# 	Phase train
# 	Loss 0.00023766914455336519
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 62999
# 	Phase train
# 	Loss 0.0002245613850391237
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 63999
# 	Phase train
# 	Loss 0.0002448131490382366
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 64999
# 	Phase train
# 	Loss 0.00032133248532772996
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 65999
# 	Phase train
# 	Loss 0.0003218557612854056
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 66999
# 	Phase train
# 	Loss 0.00020744985522469506
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 67999
# 	Phase train
# 	Loss 0.00020342832249298226
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 68999
# 	Phase train
# 	Loss 0.0002209269950981252
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 69999
# 	Phase train
# 	Loss 0.00021792922416352667
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 70999
# 	Phase train
# 	Loss 0.0001703526304481784
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 71999
# 	Phase train
# 	Loss 0.00015124950914469082
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 72999
# 	Phase train
# 	Loss 0.0064947904902510345
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 73999
# 	Phase train
# 	Loss 0.0019273648504167795
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 74999
# 	Phase train
# 	Loss 0.0003447790677455487
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 75999
# 	Phase train
# 	Loss 0.0006466418199124746
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 76999
# 	Phase train
# 	Loss 0.007175864127930254
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 77999
# 	Phase train
# 	Loss 0.0001581074575369712
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 78999
# 	Phase train
# 	Loss 0.00020108470380364452
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 79999
# 	Phase train
# 	Loss 0.00014323877257993445
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 80999
# 	Phase train
# 	Loss 0.0001180676572403172
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 81999
# 	Phase train
# 	Loss 0.0002628021684358828
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 82999
# 	Phase train
# 	Loss 0.0001158989362011198
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 83999
# 	Phase train
# 	Loss 0.00010888730867009144
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 84999
# 	Phase train
# 	Loss 0.006053637363947928
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 85999
# 	Phase train
# 	Loss 0.013064182479865849
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 86999
# 	Phase train
# 	Loss 0.00040784345765132457
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 87999
# 	Phase train
# 	Loss 9.855844018602511e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 88999
# 	Phase train
# 	Loss 0.00018625075426825788
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 89999
# 	Phase train
# 	Loss 0.00035783379280474037
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 90999
# 	Phase train
# 	Loss 0.0013749633508268744
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 91999
# 	Phase train
# 	Loss 8.927380804379936e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 92999
# 	Phase train
# 	Loss 0.00018840329721570015
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 93999
# 	Phase train
# 	Loss 9.323738504463108e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 94999
# 	Phase train
# 	Loss 0.0006151253874122631
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 95999
# 	Phase train
# 	Loss 0.0002062069052044535
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 96999
# 	Phase train
# 	Loss 8.269218415080104e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 97999
# 	Phase train
# 	Loss 0.002801192953484133
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 98999
# 	Phase train
# 	Loss 0.0005198936196393333
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 99999
# 	Phase train
# 	Loss 0.00043000184086849913
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 100999
# 	Phase train
# 	Loss 0.00021242175171209965
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 101999
# 	Phase train
# 	Loss 0.0006781034462619573
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 102999
# 	Phase train
# 	Loss 6.746674989699386e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 103999
# 	Phase train
# 	Loss 0.004993974871467799
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 104999
# 	Phase train
# 	Loss 6.416173982870532e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 105999
# 	Phase train
# 	Loss 6.123273851699196e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 106999
# 	Phase train
# 	Loss 0.0017166621255455539
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 107999
# 	Phase train
# 	Loss 0.0042941413703374565
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 108999
# 	Phase train
# 	Loss 0.00013884783038520254
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 109999
# 	Phase train
# 	Loss 0.0006434136521420442
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 110999
# 	Phase train
# 	Loss 0.00028513462166301906
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 111999
# 	Phase train
# 	Loss 0.0008482257107971236
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 112999
# 	Phase train
# 	Loss 7.033960355329327e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 113999
# 	Phase train
# 	Loss 4.9252453209192026e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 114999
# 	Phase train
# 	Loss 0.002251498866826296
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 115999
# 	Phase train
# 	Loss 0.0001254503513337113
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 116999
# 	Phase train
# 	Loss 0.00022580843688047025
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 117999
# 	Phase train
# 	Loss 6.373755786626134e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 118999
# 	Phase train
# 	Loss 4.3165454826521454e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 119999
# 	Phase train
# 	Loss 5.418798309619888e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 120999
# 	Phase train
# 	Loss 0.00010529919018154033
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 121999
# 	Phase train
# 	Loss 0.00010997828212566674
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 122999
# 	Phase train
# 	Loss 5.1634347073559184e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 123999
# 	Phase train
# 	Loss 0.0003451803313510027
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 124999
# 	Phase train
# 	Loss 0.0001893298303912161
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 125999
# 	Phase train
# 	Loss 0.0012061347515555099
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 126999
# 	Phase train
# 	Loss 0.0003229125068173744
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 127999
# 	Phase train
# 	Loss 0.00016882195996004157
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 128999
# 	Phase train
# 	Loss 3.39627936227771e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 129999
# 	Phase train
# 	Loss 0.0047201833804138005
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 130999
# 	Phase train
# 	Loss 0.002035848519881256
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 131999
# 	Phase train
# 	Loss 0.0007689643462072127
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 132999
# 	Phase train
# 	Loss 0.001329024977167137
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 133999
# 	Phase train
# 	Loss 3.4085232073266525e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 134999
# 	Phase train
# 	Loss 3.392500821064459e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 135999
# 	Phase train
# 	Loss 4.760247429658193e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 136999
# 	Phase train
# 	Loss 3.822844973910833e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 137999
# 	Phase train
# 	Loss 0.0004616359801730141
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 138999
# 	Phase train
# 	Loss 0.0007926723556010984
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 139999
# 	Phase train
# 	Loss 0.0017526821175124496
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 140999
# 	Phase train
# 	Loss 0.0024073036620393395
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 141999
# 	Phase train
# 	Loss 7.718914639553986e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 142999
# 	Phase train
# 	Loss 2.9489973712770734e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 143999
# 	Phase train
# 	Loss 0.0005297016541589983
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 144999
# 	Phase train
# 	Loss 3.4188245990662836e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 145999
# 	Phase train
# 	Loss 3.135964743705699e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 146999
# 	Phase train
# 	Loss 2.7199037958780536e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 147999
# 	Phase train
# 	Loss 2.699899459912558e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 148999
# 	Phase train
# 	Loss 2.5402819119335618e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 149999
# 	Phase train
# 	Loss 2.511043203412555e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 150999
# 	Phase train
# 	Loss 3.126821684418246e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 151999
# 	Phase train
# 	Loss 3.781788063861313e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 152999
# 	Phase train
# 	Loss 2.436826844132156e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 153999
# 	Phase train
# 	Loss 0.0007846060252632014
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 154999
# 	Phase train
# 	Loss 0.00039911380008561537
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 155999
# 	Phase train
# 	Loss 0.0005140004068380222
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 156999
# 	Phase train
# 	Loss 0.002179959381464869
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 157999
# 	Phase train
# 	Loss 0.001456273254007101
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 158999
# 	Phase train
# 	Loss 2.1830431705893716e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 159999
# 	Phase train
# 	Loss 2.1452947748912266e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 160999
# 	Phase train
# 	Loss 0.008079330204054713
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 161999
# 	Phase train
# 	Loss 0.008516892325133085
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 162999
# 	Phase train
# 	Loss 3.450213080213871e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 163999
# 	Phase train
# 	Loss 6.509512877528323e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 164999
# 	Phase train
# 	Loss 2.1618803202727577e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 165999
# 	Phase train
# 	Loss 3.657349725472159e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 166999
# 	Phase train
# 	Loss 0.0019925680244341493
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 167999
# 	Phase train
# 	Loss 0.0021073433163110167
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 168999
# 	Phase train
# 	Loss 2.527980950617348e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 169999
# 	Phase train
# 	Loss 0.0068011689581908286
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 170999
# 	Phase train
# 	Loss 8.338939187524375e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 171999
# 	Phase train
# 	Loss 0.0003608317238104064
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 172999
# 	Phase train
# 	Loss 0.00014793529771850444
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 173999
# 	Phase train
# 	Loss 2.620057807689591e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 174999
# 	Phase train
# 	Loss 0.00014711912808706984
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 175999
# 	Phase train
# 	Loss 0.0002326335907127941
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 176999
# 	Phase train
# 	Loss 0.0011372361914254725
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 177999
# 	Phase train
# 	Loss 3.3707328384480206e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 178999
# 	Phase train
# 	Loss 0.00012109087037970312
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 179999
# 	Phase train
# 	Loss 0.0002595047426439123
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 180999
# 	Phase train
# 	Loss 0.001269410175154917
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 181999
# 	Phase train
# 	Loss 0.0004223600808472838
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 182999
# 	Phase train
# 	Loss 4.9501232297188835e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 183999
# 	Phase train
# 	Loss 0.0018269621359650046
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 184999
# 	Phase train
# 	Loss 2.37735530390637e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 185999
# 	Phase train
# 	Loss 1.9632751900644507e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 186999
# 	Phase train
# 	Loss 2.4423642571491655e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 187999
# 	Phase train
# 	Loss 0.009340283926576376
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 188999
# 	Phase train
# 	Loss 0.0005713048303732648
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 189999
# 	Phase train
# 	Loss 0.00017327311797998846
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 190999
# 	Phase train
# 	Loss 8.27976873551961e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 191999
# 	Phase train
# 	Loss 4.666442328016274e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 192999
# 	Phase train
# 	Loss 4.916746866001631e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 193999
# 	Phase train
# 	Loss 0.001540945318993181
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 194999
# 	Phase train
# 	Loss 1.84569494194875e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 195999
# 	Phase train
# 	Loss 0.0016448783571831882
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 196999
# 	Phase train
# 	Loss 1.691754027888237e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 197999
# 	Phase train
# 	Loss 5.768761820945656e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 198999
# 	Phase train
# 	Loss 0.0007162656693253666
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 199999
# 	Phase train
# 	Loss 0.00018472036936145741
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 200999
# 	Phase train
# 	Loss 3.537669726938475e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 201999
# 	Phase train
# 	Loss 1.463784519728506e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 202999
# 	Phase train
# 	Loss 8.705492200533627e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 203999
# 	Phase train
# 	Loss 0.0028040942270308733
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 204999
# 	Phase train
# 	Loss 0.0002704628132050857
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 205999
# 	Phase train
# 	Loss 4.316106787882745e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 206999
# 	Phase train
# 	Loss 0.00013729502825299278
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 207999
# 	Phase train
# 	Loss 3.7971706660755444e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 208999
# 	Phase train
# 	Loss 0.003306080907350406
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 209999
# 	Phase train
# 	Loss 7.887861647759564e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 210999
# 	Phase train
# 	Loss 0.0015763256815262139
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 211999
# 	Phase train
# 	Loss 2.004144403144892e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 212999
# 	Phase train
# 	Loss 0.0012214340240461752
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 213999
# 	Phase train
# 	Loss 1.6723705812182743e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 214999
# 	Phase train
# 	Loss 0.00010532330816204194
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 215999
# 	Phase train
# 	Loss 0.0001029189570544986
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 216999
# 	Phase train
# 	Loss 0.0008109225091175176
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 217999
# 	Phase train
# 	Loss 0.0008655019482830539
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 218999
# 	Phase train
# 	Loss 3.869721558658057e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 219999
# 	Phase train
# 	Loss 1.2141596016590483e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 220999
# 	Phase train
# 	Loss 0.000143834792652342
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 221999
# 	Phase train
# 	Loss 0.00016202181723201647
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 222999
# 	Phase train
# 	Loss 1.2633727010324947e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 223999
# 	Phase train
# 	Loss 1.181977791020472e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 224999
# 	Phase train
# 	Loss 3.681626640172908e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 225999
# 	Phase train
# 	Loss 0.00017369221131957602
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 226999
# 	Phase train
# 	Loss 2.7550906452233903e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 227999
# 	Phase train
# 	Loss 0.0009290569178119767
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 228999
# 	Phase train
# 	Loss 3.278423173469491e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 229999
# 	Phase train
# 	Loss 0.0008004144910955802
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 230999
# 	Phase train
# 	Loss 1.2044448112646933e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 231999
# 	Phase train
# 	Loss 0.0057922531850636005
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 232999
# 	Phase train
# 	Loss 1.259590567315172e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 233999
# 	Phase train
# 	Loss 4.3555507545534056e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 234999
# 	Phase train
# 	Loss 3.93518321288866e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 235999
# 	Phase train
# 	Loss 2.054722676803067e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 236999
# 	Phase train
# 	Loss 0.001727728929836303
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 237999
# 	Phase train
# 	Loss 0.0007459262633346952
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 238999
# 	Phase train
# 	Loss 4.721987670563976e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 239999
# 	Phase train
# 	Loss 0.000829037897347007
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 240999
# 	Phase train
# 	Loss 0.0007847823289921507
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 241999
# 	Phase train
# 	Loss 0.00043879634176846594
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 242999
# 	Phase train
# 	Loss 1.4369860764418263e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 243999
# 	Phase train
# 	Loss 5.224101187195629e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 244999
# 	Phase train
# 	Loss 0.004823123221285641
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 245999
# 	Phase train
# 	Loss 0.00012071493620169349
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 246999
# 	Phase train
# 	Loss 4.0756515318207676e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 247999
# 	Phase train
# 	Loss 2.0587860035448102e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 248999
# 	Phase train
# 	Loss 0.0002136426446668338
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
#
# Epoch 249999
# 	Phase train
# 	Loss 1.2697173360720626e-05
# 	Phase val
# 	Loss 0.0
# 	Phase test
# 	Loss 0.0
